# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.arange(0,10)
y = np.arange(10,20)

# %%
plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph 2D')
plt.savefig('test.png')

# %%
y = x*x

# %%
plt.plot(x,y,)

# %%
plt.plot(x,y,'r--') #read the prompt shift + tab

# %%
np.pi
# Out:
# 3.141592653589793

# %%
a = np.arange(0,5 * np.pi,0.1)

# %%
y_sin = np.sin(a)
x_cos = np.cos(a)

# %%
plt.plot(a, x_cos, 'r+')

# %%
#pie chart

# %%
labels = 'Python','C++','Ruby','Java'
sizes = [215,130,245,210]
colors = ['gold','yellowgreen','lightcoral','blue']
explode = (0.4,0,0,0.2)

plt.pie(sizes, explode = explode, labels = labels, colors = colors, autopct = '%1.1f$', shadow = True)

plt.axis('equal')
plt.show()
